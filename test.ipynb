# %%
import numpy as np
import control as co
import matplotlib.pyplot as plt

L, C = 1000e-6, 10e-3
A = co.tf([1, 0, 1 / (L * C)], [1])
T = co.tf([1, 0, 0, 0, 0], [1]) / (A * A)

t, y = co.step_response(T, np.linspace(0, 1, 100000))

plt.plot(t, y)
